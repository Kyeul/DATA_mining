# %%
import pandas as pd
pd.set_option('display.max_row', 100)

# %%
bookData = pd.read_csv('AI_Book_Data.csv')

# %%
bookData.head()
# Out:
#                              제목  \
# 0                           에이트
# 1                       슈퍼인텔리전스
# 2                      핸즈온 머신러닝
# 3                      우리 아이 AI
# 4  십 대가 알아야 할 인공지능과 4차 산업혁명의 미래
#
#                                                부제       저자      분야       출판일  \
# 0                        인공지능에게 대체되지 않는 나를 만드는 법       이지성    자기계발  20191021
# 1                                     경로, 위험, 전략    닉 보스트롬    자연과학  20170405
# 2         사이킷런, 케라스, 텐서플로 2를 활용한 머신러닝, 딥러닝 완벽 실무   오렐리앙 제롱  IT 모바일  20200504
# 3                            4차산업혁명시대 인공지능 융합교육법        박찬   사회 정치  20200302
# 4  인간의 삶, 사회 그리고 컴퓨터 과학 기술을 함께 보다! 처음 만나는 디지털인문학       전승민     청소년  20180520
#
#         출판사     가격                                                 목차  \
# 0      차이정원  17000  \r\n당신에게 묻는다prologue 잡스는 왜 죽기 직전까지 인공지능을 붙잡고 있...
# 1  까치(까치글방)  25000  \r\n아직 끝이 나지 않은 이야기 : 참새와 부엉이의 우화서문감사의 글1 과거의 ...
# 2     한빛미디어  55000  \r\n[PART 1 머신러닝]CHAPTER 1 한눈에 보는 머신러닝1.1 머신러닝...
# 3  다빈치books  24000  \r\n1. 인공지능 시대- 패러다임 전환인공지능의 이해 머신러닝과 딥러닝 활용 핀...
# 4       팜파스  13000  \r\n들어가는 글Chapter 1 누구도 예측하지 못한 신세계가 열리다 -자동화 ...
#
#                                                   소개  \
# 0  \r\n하버드·스탠퍼드·NASA·구글……아이비리그와 실리콘밸리의 천재들은 인공지능 ...
# 1  \r\n2014년 출간 이후 [뉴욕 타임스], 아마존 베스트셀러영미권에서 13만 부...
# 2  \r\n머신러닝 전문가로 이끄는 최고의 실전 지침서 텐서플로 2.0을 반영한 풀컬러...
# 3  \r\n인공지능 교육에는 패러다임 전환이 필요하다!인공지능 시대의 융합교육법초격차의...
# 4  \r\n이세돌과 알파고의 대국 이후 다양한 매체에서 ‘바야흐로 4차 산업혁명의 시대...
#
#                                                출판사제공      판매지수
# 0         인류가 단 한 번도 경험하지 못한 시대가 오고 있다!『리딩으로 리드하라...  492924.0
# 1        \r 2016년 알파고와 한국 프로 바둑기사 이세돌의 대국은 전 세계적인...   24735.0
# 2         컬러판으로 돌아온 아마존 인공지능 분야 부동의 1위 도서머신러닝 전문가...   19695.0
# 3         학교와 가정에서 우리 아이들과 함께 인공지능 교육을 시작하세요더 많은 ...   11241.0
# 4        \r 인간만의 고유한 가치, 인문학적 감각! 이제 컴퓨터과학과 인문학을 ...   43659.0

# %%
len(bookData)
# Out:
# 595

# %%
bookData['판매지수'][0]
# Out:
# '<span class="gd_sellNum">\n<em class="divi">|</em>\r\n                판매지수 491301 <a class="bgYUI ico_comm ico_help" href="javascript:void(0);" onclick="openlayerBaseNew(\'dPop_sellNumberIs\',this,true,373)">판매지수란?</a>\n</span>'

# %%
#카테고리 별 빈도수
feildList = pd.Series(bookData['분야'])
result = feildList.value_counts()
result
# Out:
# IT 모바일        136
# 전집            131
# 경제 경영         113
# 대학교재           59
# 어린이            49
# 인문             45
# 사회 정치          37
# 자연과학           31
# 소설/시/희곡        28
# 청소년            21
# 가정 살림          11
# 자기계발            9
# 수험서 자격증         6
# 예술              2
# 국어 외국어 사전       2
# 종교              2
# 건강 취미           2
# 휴고상 수상작         1
# 볼로냐 라가치  상      1
# 유아              1
# Name: 분야, dtype: int64

# %%
bookData.drop(bookData[bookData['분야'].isin(['휴고상 수상작'])].index)
# Out:
#                                     제목  \
# 0                                  에이트
# 1                             핸즈온 머신러닝
# 2                              슈퍼인텔리전스
# 3                             우리 아이 AI
# 4         십 대가 알아야 할 인공지능과 4차 산업혁명의 미래
# ..                                 ...
# 681  서바이벌 만화 과학상식 살아남기 최신간 베스트6권/셀카봉증정
# 682                         왜 로봇의 도덕인가
# 683                          창의성이 뭐길래?
# 684                           핸즈온 머신러닝
# 685               파이썬 라이브러리를 활용한 머신러닝
#
#                                                  부제        저자      분야  \
# 0                          인공지능에게 대체되지 않는 나를 만드는 법        이지성    자기계발
# 1           사이킷런, 케라스, 텐서플로 2를 활용한 머신러닝, 딥러닝 완벽 실무    오렐리앙 제롱  IT 모바일
# 2                                       경로, 위험, 전략     닉 보스트롬    자연과학
# 3                              4차산업혁명시대 인공지능 융합교육법         박찬   사회 정치
# 4    인간의 삶, 사회 그리고 컴퓨터 과학 기술을 함께 보다! 처음 만나는 디지털인문학        전승민     청소년
# ..                                              ...       ...     ...
# 681                       인공지능2권,알레르기2권,쓰레기섬,아쿠아리움        편집부      전집
# 682             스스로 판단하는 인공지능 시대에 필요한 컴퓨터 윤리의 모든 것     웬델 월러치      인문
# 683                            인공지능 시대의 창의성 키우는 방법        장은영    자기계발
# 684                   사이킷런과 텐서플로를 활용한 머신러닝, 딥러닝 실무    오렐리앙 제롱  IT 모바일
# 685                 사이킷런 핵심 개발자가 쓴 머신러닝과 데이터과학 실무서   안드레아스 뮐러  IT 모바일
#
#           출판일       출판사     가격  \
# 0    20191021      차이정원  17000
# 1    20200504     한빛미디어  55000
# 2    20170405  까치(까치글방)  25000
# 3    20200302  다빈치books  24000
# 4    20180520       팜파스  13000
# ..        ...       ...    ...
# 681  20190110  아이세움(전집)  63600
# 682  20140530    메디치미디어  21000
# 683  20180601       솔과학  15000
# 684  20180417     한빛미디어  33000
# 685  20170701     한빛미디어  30000
#
#                                                     목차  \
# 0    \r\n당신에게 묻는다prologue 잡스는 왜 죽기 직전까지 인공지능을 붙잡고 있...
# 1    \r\n[PART 1 머신러닝]CHAPTER 1 한눈에 보는 머신러닝1.1 머신러닝...
# 2    \r\n아직 끝이 나지 않은 이야기 : 참새와 부엉이의 우화서문감사의 글1 과거의 ...
# 3    \r\n1. 인공지능 시대- 패러다임 전환인공지능의 이해 머신러닝과 딥러닝 활용 핀...
# 4    \r\n들어가는 글Chapter 1 누구도 예측하지 못한 신세계가 열리다 -자동화 ...
# ..                                                 ...
# 681     \r\n\n\n\n
# 682  \r\n예일 대학교의 생명윤리를 위한 학제간 센터(Interdisciplinary ...
# 683  \r\n프롤로그추천사(가나다순)PART 1 창의성은 왜 필요한가1 알파고의 시대, ...
# 684  \r\n1부. 머신러닝1장. 한눈에 보는 머신러닝1.1 머신러닝이란?1.2 왜 머신...
# 685  \r\nCHAPTER 1 소개1.1 왜 머신러닝인가?__1.1.1 머신러닝으로 풀 ...
#
#                                                     소개  \
# 0    \r\n하버드·스탠퍼드·NASA·구글……아이비리그와 실리콘밸리의 천재들은 인공지능 ...
# 1    \r\n머신러닝 전문가로 이끄는 최고의 실전 지침서 텐서플로 2.0을 반영한 풀컬러...
# 2    \r\n2014년 출간 이후 [뉴욕 타임스], 아마존 베스트셀러영미권에서 13만 부...
# 3    \r\n인공지능 교육에는 패러다임 전환이 필요하다!인공지능 시대의 융합교육법초격차의...
# 4    \r\n이세돌과 알파고의 대국 이후 다양한 매체에서 ‘바야흐로 4차 산업혁명의 시대...
# ..                                                 ...
# 681     \r\n\n\n\n
# 682  \r\n로봇의 윤리에 대한 포괄적인 안내서  공상과학 소설과 영화를 통해 꾸준히 제...
# 683  \r\n프롤로그추천사(가나다순)PART 1 창의성은 왜 필요한가1 알파고의 시대, ...
# 684  \r\n인공지능 분야에 종사한다면 반드시 읽어야 하는 머신러닝 전문가로 이끄는 최고...
# 685  \r\n사이킷런 핵심 개발자에게 배우는 머신러닝 이론과 구현 현업에서 머신러닝을 연...
#
#                                                  출판사제공  \
# 0           인류가 단 한 번도 경험하지 못한 시대가 오고 있다!『리딩으로 리드하라...
# 1           컬러판으로 돌아온 아마존 인공지능 분야 부동의 1위 도서머신러닝 전문가...
# 2          \r 2016년 알파고와 한국 프로 바둑기사 이세돌의 대국은 전 세계적인...
# 3           학교와 가정에서 우리 아이들과 함께 인공지능 교육을 시작하세요더 많은 ...
# 4          \r 인간만의 고유한 가치, 인문학적 감각! 이제 컴퓨터과학과 인문학을 ...
# ..                                                 ...
# 681                                                NaN
# 682        \r  왜 로봇의 도덕이 필요한가?  현대에는 자동차에서부터 쓰레기통에 ...
# 683                                                NaN
# 684         아마존 인공지능 분야 부동의 1위 도서 이 책의 원서는 출간 직후부터 ...
# 685        \r 실제 문제에 대한 해법을 찾는 머신러닝 기술자를 위한 본격 머신러닝...
#
#                                                   판매지수
# 0    <span class="gd_sellNum">\n<em class="divi">|<...
# 1    <span class="gd_sellNum">\n<em class="divi">|<...
# 2    <span class="gd_sellNum">\n<em class="divi">|<...
# 3    <span class="gd_sellNum">\n<em class="divi">|<...
# 4    <span class="gd_sellNum">\n<em class="divi">|<...
# ..                                                 ...
# 681  <span class="gd_sellNum">\n<em class="divi">|<...
# 682                                                NaN
# 683  <span class="gd_sellNum">\n<em class="divi">|<...
# 684  <span class="gd_sellNum">\n<em class="divi">|<...
# 685                                                NaN
#
# [686 rows x 11 columns]

# %%
bookData[bookData['분야'].isin(['휴고상 수상작'])].index
# Out:
# Int64Index([686], dtype='int64')
